# %% [markdown]
# ### Integrantes

# %% [markdown]
# 550562 - Larissa Akemi Iwamoto
#
# 98163 - Júlia Martins Santana Figueiredo

# %% [markdown]
# ### Carregando os dados e fazendo análise exploratória

# %%
# Bibliotecas para uso e visualização de dados
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Trabalhando com dados em tabelas
import pandas as pd

# Trabalhando com gráficos
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados = pd.read_csv('C:/Users/logonrmlocal/Desktop/CPAI/CP/solicitacoescredito.csv') # Carregando o arquivo XLSX

# %%
dados.head() #Visualizando o dataset
# Out:
#    numero_solicitacao             razaoSocial        nomeFantasia  \
# 0                   1  James Richardson-Patel  Alexandra Williams
# 1                   2      Dr. Geoffrey Walsh   Mr. Darren Arnold
# 2                   3           Joanna Hudson      Dr. David Rees
# 3                   4    Gordon Jones-Hopkins    Sara Reid-Robson
# 4                   5               Nigel Lee  Dr. Stanley Duncan
#
#          cnpjSemTraco  maiorAtraso  margemBrutaAcumulada  percentualProtestos  \
# 0  KEBE17609492220843            0              0.252448                  0.0
# 1  JRBK88908250677300            0              0.000000                  NaN
# 2  GCVQ28531614261293            4              0.624777                  0.0
# 3  KJND32266018316396           20              0.000000                  NaN
# 4  CGQN15826802440348           20              0.454088                  0.0
#
#         primeiraCompra  prazoMedioRecebimentoVendas  titulosEmAberto  ...  \
# ...

# %%
dados.columns # listando as colunas existentes
# Out:
# Index(['numero_solicitacao', 'razaoSocial', 'nomeFantasia', 'cnpjSemTraco',
#        'maiorAtraso', 'margemBrutaAcumulada', 'percentualProtestos',
#        'primeiraCompra', 'prazoMedioRecebimentoVendas', 'titulosEmAberto',
#        'valorSolicitado', 'status', 'definicaoRisco',
#        'diferencaPercentualRisco', 'percentualRisco', 'dashboardCorrelacao',
#        'valorAprovado', 'dataAprovadoEmComite', 'periodoBalanco',
#        'ativoCirculante', 'passivoCirculante', 'totalAtivo',
#        'totalPatrimonioLiquido', 'endividamento', 'duplicatasAReceber',
#        'estoque', 'faturamentoBruto', 'margemBruta',
#        'periodoDemonstrativoEmMeses', 'custos', 'anoFundacao',
#        'intervaloFundacao', 'capitalSocial', 'restricoes', 'empresa_MeEppMei',
#        'scorePontualidade', 'limiteEmpresaAnaliseCredito',
#        'dataAprovadoNivelAnalista'],
#       dtype='object')

# %%
dados.shape #verificando as dimensões dos dados
# Out:
# (8973, 38)

# %%
dados.info() #informações sobre os tipos de dados e valores ausentes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8973 entries, 0 to 8972
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   numero_solicitacao           8973 non-null   int64
#  1   razaoSocial                  8973 non-null   object
#  2   nomeFantasia                 8973 non-null   object
#  3   cnpjSemTraco                 8973 non-null   object
#  4   maiorAtraso                  8973 non-null   int64
#  5   margemBrutaAcumulada         8973 non-null   float64
#  6   percentualProtestos          7475 non-null   float64
#  7   primeiraCompra               8867 non-null   object
#  8   prazoMedioRecebimentoVendas  8973 non-null   int64
#  9   titulosEmAberto              8973 non-null   float64
#  10  valorSolicitado              8973 non-null   int64
#  11  status                       8973 non-null   object
#  12  definicaoRisco               8973 non-null   object
# ...

# %%
dados.isnull().sum() # Ver se tem dados nulos (células vazias)
# Out:
# numero_solicitacao                0
# razaoSocial                       0
# nomeFantasia                      0
# cnpjSemTraco                      0
# maiorAtraso                       0
# margemBrutaAcumulada              0
# percentualProtestos            1498
# primeiraCompra                  106
# prazoMedioRecebimentoVendas       0
# titulosEmAberto                   0
# valorSolicitado                   0
# status                            0
# definicaoRisco                    0
# diferencaPercentualRisco          0
# percentualRisco                   0
# dashboardCorrelacao               0
# valorAprovado                  1404
# dataAprovadoEmComite           8415
# periodoBalanco                 4240
# ativoCirculante                4240
# passivoCirculante              4240
# totalAtivo                     4240
# totalPatrimonioLiquido         4240
# endividamento                  4240
# duplicatasAReceber             4240
# estoque                        4240
# ...

# %%
dados.describe() #calculando estatísticas descritivas
# Out:
#        numero_solicitacao  maiorAtraso  margemBrutaAcumulada  \
# count         8973.000000  8973.000000           8973.000000
# mean          4550.042015    24.642594              0.362176
# std           2603.485853    66.180793              0.201455
# min              1.000000     0.000000              0.000000
# 25%           2316.000000     3.000000              0.281395
# 50%           4559.000000     6.000000              0.402895
# 75%           6802.000000    22.000000              0.507860
# max           9045.000000  1265.000000              1.000000
#
#        percentualProtestos  prazoMedioRecebimentoVendas  titulosEmAberto  \
# count          7475.000000                  8973.000000     8.973000e+03
# mean              0.019260                    23.083027     6.487101e+04
# std               0.593579                    68.177649     2.482852e+05
# min               0.000000                     0.000000     0.000000e+00
# ...

# %%
dados.dtypes #informações sobre as colunas e os seus tipos de dados
# Out:
# numero_solicitacao               int64
# razaoSocial                     object
# nomeFantasia                    object
# cnpjSemTraco                    object
# maiorAtraso                      int64
# margemBrutaAcumulada           float64
# percentualProtestos            float64
# primeiraCompra                  object
# prazoMedioRecebimentoVendas      int64
# titulosEmAberto                float64
# valorSolicitado                  int64
# status                          object
# definicaoRisco                  object
# diferencaPercentualRisco       float64
# percentualRisco                float64
# dashboardCorrelacao            float64
# valorAprovado                  float64
# dataAprovadoEmComite            object
# periodoBalanco                  object
# ativoCirculante                float64
# passivoCirculante              float64
# totalAtivo                     float64
# totalPatrimonioLiquido         float64
# endividamento                  float64
# ...

# %% [markdown]
# ### Lidando com dados ausentes

# %%
#Primeiro lidando com dados ausentes
#Ver o shape antes
shape_antes = dados.shape
print("Antes:\t", shape_antes)

dados.dropna(subset=['percentualProtestos'], inplace=True)
dados.dropna(subset=['periodoDemonstrativoEmMeses'], inplace=True)
dados.dropna(subset=['custos'], inplace=True)
dados.dropna(subset=['anoFundacao'], inplace=True)
dados.dropna(subset=['intervaloFundacao'], inplace=True)
dados.dropna(subset=['capitalSocial'], inplace=True)
dados.dropna(subset=['restricoes'], inplace=True)
dados.dropna(subset=['empresa_MeEppMei'], inplace=True)
dados.dropna(subset=['limiteEmpresaAnaliseCredito'], inplace=True)
dados.dropna(subset=['dataAprovadoNivelAnalista'], inplace=True)
dados.dropna(subset=['razaoSocial'], inplace=True)
dados.dropna(subset=['primeiraCompra'], inplace=True)
dados.dropna(subset=['status'], inplace=True)
dados.dropna(subset=['definicaoRisco'], inplace=True)
dados.dropna(subset=['dataAprovadoEmComite'], inplace=True)
dados.dropna(subset=['periodoBalanco'], inplace=True)

#Ver o shape depois
shape_depois = dados.shape
print("Depois:\t", shape_depois)
# Out:
# Antes:	 (0, 38)
# Depois:	 (0, 38)

# %%
# Removendo duplicatas
dados.drop_duplicates(inplace=True)
dados.shape
# Out:
# (0, 38)

# %% [markdown]
# ### Convertendo string para float

# %%
# Convertendo a coluna para float, porém nesse método cria várias colunas
aux = pd.get_dummies(dados["cnpjSemTraco"], drop_first=True)
df_final = pd.concat([dados, aux], axis=1)

# %%
df_final.head()  # Vendo as colunas criadas
# Out:
# Empty DataFrame
# Columns: [numero_solicitacao, razaoSocial, nomeFantasia, cnpjSemTraco, maiorAtraso, margemBrutaAcumulada, percentualProtestos, primeiraCompra, prazoMedioRecebimentoVendas, titulosEmAberto, valorSolicitado, status, definicaoRisco, diferencaPercentualRisco, percentualRisco, dashboardCorrelacao, valorAprovado, dataAprovadoEmComite, periodoBalanco, ativoCirculante, passivoCirculante, totalAtivo, totalPatrimonioLiquido, endividamento, duplicatasAReceber, estoque, faturamentoBruto, margemBruta, periodoDemonstrativoEmMeses, custos, anoFundacao, intervaloFundacao, capitalSocial, restricoes, empresa_MeEppMei, scorePontualidade, limiteEmpresaAnaliseCredito, dataAprovadoNivelAnalista]
# Index: []
#
# [0 rows x 38 columns]

# %%
# Importação do LabelEncoder
from sklearn.preprocessing import LabelEncoder

# %%
# Criando o LabelEncoder
le = LabelEncoder()

# Convertendo strings em números
dados['cnpjSemTraco'] = le.fit_transform(dados['cnpjSemTraco'])
dados['nomeFantasia'] = le.fit_transform(dados['nomeFantasia'])

# %%
dados.head()  # Visualizando o dataset
# Out:
# Empty DataFrame
# Columns: [numero_solicitacao, razaoSocial, nomeFantasia, cnpjSemTraco, maiorAtraso, margemBrutaAcumulada, percentualProtestos, primeiraCompra, prazoMedioRecebimentoVendas, titulosEmAberto, valorSolicitado, status, definicaoRisco, diferencaPercentualRisco, percentualRisco, dashboardCorrelacao, valorAprovado, dataAprovadoEmComite, periodoBalanco, ativoCirculante, passivoCirculante, totalAtivo, totalPatrimonioLiquido, endividamento, duplicatasAReceber, estoque, faturamentoBruto, margemBruta, periodoDemonstrativoEmMeses, custos, anoFundacao, intervaloFundacao, capitalSocial, restricoes, empresa_MeEppMei, scorePontualidade, limiteEmpresaAnaliseCredito, dataAprovadoNivelAnalista]
# Index: []
#
# [0 rows x 38 columns]

# %% [markdown]
# ### Gráficos

# %%
dados.hist(figsize=(20,21)); #distribuição das variáveis qualitativas

# %%
plt.title('Relação entre CNPJ e Margem Bruta Acumulada')
plt.xlabel("CNPJ")
plt.ylabel("Margem Bruta Acumulada")

sns.scatterplot(x='cnpjSemTraco', y='margemBrutaAcumulada', data=dados)

plt.show()

# %%
plt.hist(dados['custos'], bins=100)


plt.title('Histograma dos Custos')
plt.xlabel('Custos')
plt.ylabel('Contagem')
plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(dados['cnpjSemTraco'], dados['capitalSocial'])

# Definindo o título, rótulos do eixo x e y
ax.set_title('Capital social por CNPJ')
ax.set_xlabel('CNPJ')
ax.set_ylabel('Capital Social')

# Exibindo o gráfico
plt.show()

# %%
analise = 7.5

plt.hist(dados['limiteEmpresaAnaliseCredito'], bins=10, color='skyblue', edgecolor='black')

plt.axvline(analise, color='red', linestyle='dashed', linewidth=1)

plt.title('Distribuição da Análise de Crédito')
plt.xlabel('Frequência')
plt.ylabel('Análise de Crédito')

plt.show()

# %%
quartil_25 = dados['margemBrutaAcumulada'].quantile(0.25)
quartil_df = pd.DataFrame({'Quartil 25%': [quartil_25]})
quartil_df.plot(kind='bar')

plt.title('Quartil 25% da Margem Bruta Acumulada')
plt.xlabel('Quartil')
plt.ylabel('Margem Bruta Acumulada')

plt.show()

# %%
cols = ['numero_solicitacao', 'margemBrutaAcumulada', 'titulosEmAberto','custos']
corr_matx = dados[cols].corr()

heatmap = sns.heatmap(corr_matx,cbar=True,annot=True,square=True,fmt='.2f',annot_kws={'size': 15},yticklabels=cols,xticklabels=cols,cmap='Dark2')

# %% [markdown]
# ### Separando os grupos de clientes

# %%
grupos_clientes = dados[['nomeFantasia', 'cnpjSemTraco', 'custos']]   #Definindo os grupos

# %%
grupos_clientes.head() #Visualizando as colunas

# %%
sns.scatterplot(data = grupos_clientes, x = 'nomeFantasia', y = 'cnpjSemTraco', hue = 'custos') # Visualizando os dados com um mapa de calor

# %%
#Normalizando os dados
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(grupos_clientes[['nomeFantasia', 'cnpjSemTraco']], grupos_clientes[['custos']], test_size=0.33, random_state=0)

# %%
#Treinando e testando
from sklearn import preprocessing

X_train_norm = preprocessing.normalize(X_train)
X_test_norm = preprocessing.normalize(X_test)

# %%
#Importando o KMeans
from sklearn.cluster import KMeans

# %%
# Ajustando e avaliando o modelo
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=0, n_init='auto')
kmeans.fit(X_train_norm)

# %%
sns.scatterplot(data = X_train, x = 'nomeFantasia', y = 'cnpjSemTraco', hue = kmeans.labels_) # Visualizando o gráfico, pra ver a separação

# %% [markdown]
# ### Classificação

# %%
from sklearn.model_selection import train_test_split

# %%
# Escolhendo as colunas preditivas e alvo
x = dados.drop(columns = ['razaoSocial', 'primeiraCompra', 'status','definicaoRisco', 'dataAprovadoEmComite', 'periodoBalanco', 'intervaloFundacao', 'restricoes', 'empresa_MeEppMei', 'dataAprovadoNivelAnalista' ])
y = dados['restricoes']  # Classe alvo

# Dividindo conjunto de treinamento e conjunto de teste
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
x_train.head(5)

# %%
y_train.head(5)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
lda = LinearDiscriminantAnalysis()  # Criando o objeto do classificador

lda.fit(x_train,y_train) # Treinando o classificador passando apenas o conjunto de dados de treinamento

# %%
# Passando apenas o x de teste
y_predicoes = lda.predict(x_test)

# %%
y_predicoes

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, classification_report

# %%
matriz_confusao = confusion_matrix(y_true = y_test,
                                   y_pred = y_predicoes,
                                   labels=['True', 'False'])

# %%
# plotando uma figura com a matriz de confusao
figure = plt.figure(figsize=(15, 5))
disp = ConfusionMatrixDisplay(confusion_matrix = matriz_confusao, display_labels=['Symptoms of Depressive Disorder', 'Symptoms of Anxiety Disorder', 'Symptoms of Anxiety Disorder or Depressive Disorder'])
disp.plot(values_format='d')

# %%
accuracy_score(y_true = y_test, y_pred = y_predicoes,)

# %%
precision_score(y_true=y_test, y_pred=y_predicoes, average='micro')

# %%
# Metricas de precisão, revocação, f1-score e acurácia.
print(classification_report(y_test, y_predicoes))
